# %%
from collections import defaultdict
from typing import List, Set

class Edge:
    def __init__(self, start: str, end: str):
        self.start = start
        self.end = end

def print_vector(vec: List[str]):
    print("[" + ", ".join(sorted(map(str, vec))) + "]", end="")

def print_2D_vector(vecs: List[List[str]]):
    print("[", end="")
    for i in range(len(vecs) - 1):
        print_vector(vecs[i])
        print(", ", end="")
    print_vector(vecs[-1])
    print("]")

cliques: List[List[str]] = []      
backtrack_count: int = 0           



def bron_kerbosch(current_clique: Set[str],
                  candidates: Set[str],
                  processed_vertices: Set[str],
                  graph: defaultdict[str, Set[str]],
                  type_pivot='max_degree') -> None:
    """
    Versión con pivoting + contador de backtracks.
    """
    global cliques, backtrack_count

    # 1) Caso base: no candidatos NI excluidos  → clique maximal
    if not candidates and not processed_vertices:
        if len(current_clique) > 2:              
            cliques.append(list(current_clique))
        return

    # 2) Caso base: no candidatos PERO sí excluidos → backtracking
    if not candidates and processed_vertices:
        backtrack_count += 1
        print(f"Backtrack #{backtrack_count}: R={sorted(current_clique)}  "
              f"(X tiene {len(processed_vertices)} vértices)")
        return

    union_set = candidates.union(processed_vertices)

     # --- Selección del Pivote ---
    # Seleccionar como pivote el de mayor grado (estrategia actual para optimizar)
    if type_pivot == "max_degree":
        pivot = max(union_set, key=lambda v: len(graph[v])) 
    else: 
        # Seleccionar como pivote el de menor grado (estrategia alternativa)
        pivot = min(union_set, key=lambda v: len(graph[v]))

    possibles = candidates.difference(graph[pivot])

    for vertex in list(possibles):  
        new_clique = current_clique.union({vertex})
        new_candidates = candidates.intersection(graph[vertex])
        new_processed_vertices = processed_vertices.intersection(graph[vertex])

        bron_kerbosch(new_clique, new_candidates,
                      new_processed_vertices, graph)

        candidates.remove(vertex)
        processed_vertices.add(vertex)

def main(type_pivot: str):
    global cliques, backtrack_count

    edges = [

        Edge("A1", "B1"), Edge("B1", "A1"),
        Edge("A1", "C1"), Edge("C1", "A1"),
        Edge("A1", "D1"), Edge("D1", "A1"),
        Edge("A1", "E1"), Edge("E1", "A1"),
        Edge("A1", "F1"), Edge("F1", "A1"),

        Edge("B1", "C1"), Edge("C1", "B1"),
        Edge("B1", "D1"), Edge("D1", "B1"),
        Edge("C1", "D1"), Edge("D1", "C1"),
        Edge("E1", "F1"), Edge("F1", "E1"),



        Edge("E1", "A2"), Edge("A2", "E1"),
        Edge("A2", "F2"), Edge("F2", "A2"),
        Edge("F2", "E2"), Edge("E2", "F2"),
        Edge("A2", "E2"), Edge("E2", "A2"),



        Edge("A2", "D2"), Edge("D2", "A2"),
        Edge("A2", "C2"), Edge("C2", "A2"),
        Edge("A2", "B2"), Edge("B2", "A2"),
        Edge("B2", "C2"), Edge("C2", "B2"),
        Edge("B2", "D2"), Edge("D2", "B2"),
        Edge("D2", "C2"), Edge("C2", "D2"),


        Edge("A3", "B3"), Edge("B3", "A3"),
        Edge("A3", "C3"), Edge("C3", "A3"),
        Edge("A3", "D3"), Edge("D3", "A3"),
        Edge("B3", "C3"), Edge("C3", "B3"),

        Edge("B3", "D3"), Edge("D3", "B3"),
        Edge("D3", "C3"), Edge("C3", "D3"),
        Edge("A3", "E2"), Edge("E2", "A3"),
        Edge("A3", "F3"), Edge("F3", "A3"),


        Edge("A3", "E3"), Edge("E3", "A3"),
        Edge("F3", "E3"), Edge("E3", "F3"),

        Edge("A4", "B4"), Edge("B4", "A4"),
        Edge("A4", "C4"), Edge("C4", "A4"),
        Edge("A4", "D4"), Edge("D4", "A4"),
        Edge("B4", "C4"), Edge("C4", "B4"),
        Edge("B4", "D4"), Edge("D4", "B4"),
        Edge("C4", "D4"), Edge("D4", "C4"),
        Edge("B4", "F1"), Edge("F1", "B4"),


        Edge("A5", "B5"), Edge("B5", "A5"),
        Edge("A5", "C5"), Edge("C5", "A5"),
        Edge("A5", "D5"), Edge("D5", "A5"),
        Edge("B5", "C5"), Edge("C5", "B5"),
        Edge("B5", "D5"), Edge("D5", "B5"),
        Edge("C5", "D5"), Edge("D5", "C5"),
        Edge("E1", "B5"), Edge("B5", "E1"),
        Edge("B5","F2" ), Edge("F2", "B5"),


        Edge("A6", "B6"), Edge("B6", "A6"),
        Edge("A6", "C6"), Edge("C6", "A6"),
        Edge("A6", "D6"), Edge("D6", "A6"),
        Edge("B6", "C6"), Edge("C6", "B6"),
        Edge("B6", "D6"), Edge("D6", "B6"),
        Edge("C6", "D6"), Edge("D6", "C6"),
        Edge("B6", "E2"), Edge("E2", "B6"),
        Edge("B6", "F3"), Edge("F3", "B6"),

        Edge("A7", "B7"), Edge("B7", "A7"),
        Edge("A7", "C7"), Edge("C7", "A7"),
        Edge("A7", "D7"), Edge("D7", "A7"),
        Edge("B7", "C7"), Edge("C7", "B7"),
        Edge("B7", "D7"), Edge("D7", "B7"),
        Edge("C7", "D7"), Edge("D7", "C7"),
        Edge("B7", "E3"), Edge("E3", "B7"),


        Edge("A4", "F4"), Edge("F4", "A4"),
        Edge("F4", "E4"), Edge("E4", "F4"),
        Edge("A4", "E4"), Edge("E4", "A4"),
        Edge("E4", "A5"), Edge("A5", "E4"),

        Edge("A5", "F5"), Edge("F5", "A5"),
        Edge("A5", "E5"), Edge("E5", "A5"),
        Edge("F5", "E5"), Edge("E5", "F5"),
        Edge("E5", "A6"), Edge("A6", "E5"),

        Edge("A6", "F6"), Edge("F6", "A6"),
        Edge("E6", "A6"), Edge("A6", "E6"),
        Edge("F6", "E6"), Edge("E6", "F6"),

        Edge("E6", "A7"), Edge("A7", "E6"),
        Edge("A7", "F7"), Edge("F7", "A7"),
        Edge("A7", "E7"), Edge("E7", "A7"),
        Edge("F7", "E7"), Edge("E7", "F7")
    ]
    # Construir lista de adyacencia
    graph = defaultdict(set)
    for edge in edges:
        graph[edge.start].add(edge.end)

    # Inicializar conjuntos
    current_clique: Set[str] = set()
    candidates:      Set[str] = set(graph.keys())
    processed:       Set[str] = set()

    # Ejecutar algoritmo
    bron_kerbosch(current_clique, candidates, processed, graph, type_pivot)

    # Mostrar resultados
    cliques.sort(key=lambda x: (len(x), x))
    print("\nCliques maximales encontrados: ", end="")
    print_2D_vector(cliques)
    print(f"\nTotal de backtracks contabilizados: {backtrack_count}")
    print(f"Total clicques maximos {len(cliques)}")


print("============== CON ESTRATEGIA DE PIVOTE MAX_DEGREE ===============")
main('max_degree')
# Out:
# ============== CON ESTRATEGIA DE PIVOTE MAX_DEGREE ===============
# Backtrack #1: R=['A5', 'F5']  (X tiene 1 vértices)
# Backtrack #2: R=['A2', 'E2']  (X tiene 1 vértices)
# Backtrack #3: R=['A2', 'F2']  (X tiene 1 vértices)
# Backtrack #4: R=['A2', 'C2']  (X tiene 2 vértices)
# Backtrack #5: R=['A6', 'E6']  (X tiene 1 vértices)
# Backtrack #6: R=['A4', 'E4']  (X tiene 1 vértices)
# Backtrack #7: R=['A3', 'F3']  (X tiene 1 vértices)
# Backtrack #8: R=['A6', 'F6']  (X tiene 1 vértices)
# Backtrack #9: R=['A3', 'C3']  (X tiene 2 vértices)
# Backtrack #10: R=['A6', 'B6', 'D6']  (X tiene 1 vértices)
# Backtrack #11: R=['A1', 'E1']  (X tiene 1 vértices)
# Backtrack #12: R=['A1', 'B1']  (X tiene 2 vértices)
# Backtrack #13: R=['A7', 'F7']  (X tiene 1 vértices)
# Backtrack #14: R=['C3']  (X tiene 3 vértices)
# Backtrack #15: R=['A6', 'B6']  (X tiene 2 vértices)
# Backtrack #16: R=['C4']  (X tiene 3 vértices)
# Backtrack #17: R=['C2']  (X tiene 3 vértices)
# Backtrack #18: R=['B7']  (X tiene 4 vértices)
# Backtrack #19: R=['F7']  (X tiene 2 vértices)
# Backtrack #20: R=['B1']  (X tiene 3 vértices)
#
# Cliques maximales encontrados: [[A5, E5, F5], [A6, E6, F6], [A7, E7, F7], [A3, E3, F3], [A1, E1, F1], [A2, E2, F2], [A4, E4, F4], [A5, B5, C5, D5], [A7, B7, C7, D7], [A3, B3, C3, D3], [A1, B1, C1, D1], [A2, B2, C2, D2], [A4, B4, C4, D4], [A6, B6, C6, D6]]
#
# Total de backtracks contabilizados: 20
# Total clicques maximos 14

# %%
print("\n============== CON ESTRATEGIA DE PIVOTE DE ORDENACIÓN ALFABETICA ===============")
main('alphabetical')
# Out:
# ============== CON ESTRATEGIA DE PIVOTE DE ORDENACIÓN ALFABETICA ===============
# Backtrack #21: R=['A5', 'F5']  (X tiene 1 vértices)
# Backtrack #22: R=['A2', 'E2']  (X tiene 1 vértices)
# Backtrack #23: R=['A2', 'F2']  (X tiene 1 vértices)
# Backtrack #24: R=['A2', 'C2']  (X tiene 2 vértices)
# Backtrack #25: R=['A6', 'E6']  (X tiene 1 vértices)
# Backtrack #26: R=['A4', 'E4']  (X tiene 1 vértices)
# Backtrack #27: R=['A3', 'F3']  (X tiene 1 vértices)
# Backtrack #28: R=['E4', 'F4']  (X tiene 1 vértices)
# Backtrack #29: R=['F4']  (X tiene 2 vértices)
# Backtrack #30: R=['A6', 'F6']  (X tiene 1 vértices)
# Backtrack #31: R=['A3', 'C3']  (X tiene 2 vértices)
# Backtrack #32: R=['A6', 'B6', 'D6']  (X tiene 1 vértices)
# Backtrack #33: R=['A1', 'E1']  (X tiene 1 vértices)
# Backtrack #34: R=['A1', 'B1']  (X tiene 2 vértices)
# Backtrack #35: R=['C3']  (X tiene 3 vértices)
# Backtrack #36: R=['A6', 'B6']  (X tiene 2 vértices)
# Backtrack #37: R=['C4']  (X tiene 3 vértices)
# Backtrack #38: R=['E1']  (X tiene 4 vértices)
# Backtrack #39: R=['A7', 'B7', 'C7']  (X tiene 1 vértices)
# Backtrack #40: R=['F2']  (X tiene 3 vértices)
# Backtrack #41: R=['C2']  (X tiene 3 vértices)
# Backtrack #42: R=['A7', 'B7']  (X tiene 2 vértices)
# Backtrack #43: R=['B1']  (X tiene 3 vértices)
# Backtrack #44: R=['A6']  (X tiene 6 vértices)
# Backtrack #45: R=['D5']  (X tiene 3 vértices)
#
# Cliques maximales encontrados: [[A5, E5, F5], [A5, E5, F5], [A6, E6, F6], [A6, E6, F6], [A7, E7, F7], [A7, E7, F7], [A3, E3, F3], [A3, E3, F3], [A1, E1, F1], [A1, E1, F1], [A2, E2, F2], [A2, E2, F2], [A4, E4, F4], [A4, E4, F4], [A5, B5, C5, D5], [A5, B5, C5, D5], [A7, B7, C7, D7], [A7, B7, C7, D7], [A3, B3, C3, D3], [A3, B3, C3, D3], [A1, B1, C1, D1], [A1, B1, C1, D1], [A2, B2, C2, D2], [A2, B2, C2, D2], [A4, B4, C4, D4], [A4, B4, C4, D4], [A6, B6, C6, D6], [A6, B6, C6, D6]]
#
# Total de backtracks contabilizados: 45
# Total clicques maximos 28
